# %% [markdown]
# # HMM Market Regimes — Google Colab Launcher
#
# **Project:** Gaussian HMM for Market Regime Analysis
# **Author:** Matan Eshel
# **Course:** Advanced Methods in Machine Learning, Afeka Academic College of Engineering
# **Repository:** https://github.com/matanesh/hmm-market-regimes-final-project
#
# ---
#
# ## Purpose
#
# This notebook is a **lightweight execution launcher** for Google Colab.
# It automatically:
#
# 1. Clones the public GitHub repository.
# 2. Installs the exact Python dependencies from `requirements.txt`.
# 3. Runs the automated test suite (`pytest tests/ -q`).
# 4. Executes the final project notebook (`HMM_Market_Regimes_Project.ipynb`) from top to bottom.
# 5. Verifies that the saved experiment artifacts, tables, and figures load correctly.
#
# The main scientific notebook already contains saved outputs, so the project
# can also be reviewed directly on GitHub without rerunning the experiments.
#
# A complete re-training of all HMM experiments is optional and may take
# several minutes and require access to Yahoo Finance.

# %%
# Clone the repository
# !git clone https://github.com/matanesh/hmm-market-regimes-final-project.git
# %cd hmm-market-regimes-final-project

# %%
# Install exact dependencies
# !pip install -r requirements.txt -q

# %%
# Run the test suite
# !python -m pytest tests/ -q

# %%
# Execute the main project notebook
# !jupyter nbconvert \
  --to notebook \
  --execute HMM_Market_Regimes_Project.ipynb \
  --output HMM_Market_Regimes_Project_Executed.ipynb \
  --ExecutePreprocessor.timeout=600 \
  --ExecutePreprocessor.kernel_name=python3

# %% [markdown]
# ---
#
# ## Optional: Full HMM Re-training
#
# The cells below re-run the complete HMM robustness experiment
# (9 assets, 5 seeds, walk-forward on SPY). This may take several minutes
# and requires access to Yahoo Finance. It is **not required** for reviewing
# the project — the main notebook already contains all final results.
#
# ```python
# # python run_extended_analysis.py
# ```
#
# ```python
# # python run_supervised_baselines.py
# ```
#
# ```python
# # python analyze_extended_context.py --run-dir experiments_extended/<new_run_id>
# ```

# %% [markdown]
# ---
#
# ## Notes
#
# - This launcher notebook is **not** the main scientific notebook.
# - The authoritative notebook is `HMM_Market_Regimes_Project.ipynb`
#   which already contains all saved outputs, figures, and tables.
# - This file exists only to provide a one-click reproducible environment
#   in Google Colab.
# - All experiment artifacts are versioned in the repository under:
#   - `experiments_extended/extended_20260811_121957/`
#   - `experiments_supervised/supervised_20260811_133344/`
